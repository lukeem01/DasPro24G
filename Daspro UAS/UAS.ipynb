# %%
import pandas as pd
df = pd.read_csv("rounded_hours_student_scores.csv")
df.head(10)
# Out:
#    Hours  Scores
# 0    1.1      41
# 1    1.2      40
# 2    1.4      38
# 3    1.5      39
# 4    1.6      36
# 5    1.8      40
# 6    1.9      42
# 7    2.1      41
# 8    2.2      45
# 9    2.3      43

# %%
print("Statistika Jam dan Nilai Pelajar ")
print("Statistika Waktu belajar:")
print(df['Hours'].describe())
print("Statistika Nilai Pelajar:")
print(df['Scores'].describe())
# Out:
# Statistika Jam dan Nilai Pelajar
# Statistika Waktu belajar:
# count    60.000000
# mean      5.150000
# std       2.402365
# min       1.100000
# 25%       3.150000
# 50%       5.150000
# 75%       7.150000
# max       9.200000
# Name: Hours, dtype: float64
# Statistika Nilai Pelajar:
# count    60.000000
# mean     46.433333
# std       5.699737
# min      36.000000
# 25%      41.000000
# 50%      47.000000
# 75%      50.000000
# max      65.000000
# Name: Scores, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

x = df[['Hours']]
y = df['Scores']

model = LinearRegression()
model.fit(x, y)

beta_0 = model.intercept_
beta_1 = model.coef_[0]

print(f"Persamaan Regresi : Scores = {beta_0:.2f} + {beta_1:.2f} * Nilai")
# Out:
# Persamaan Regresi : Scores = 36.68 + 1.89 * Nilai

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(9, 5))
sns.scatterplot(x=df['Hours'], y=df['Scores'], color='green', label='Data Asli')
plt.plot(df['Hours'], model.predict(X), color='red', label='Garis Regresi')
plt.title("Regresi Linier: Jam dan Nilai")
plt.xlabel("Hours")
plt.ylabel("Score")
plt.legend()
plt.grid(True)
plt.annotate(f'Jam Belajar = {beta_0:.2f} + {beta_1:.2f} * Nilai',
             xy=(0.55, 0.9), xycoords='axes fraction', fontsize=12, color='blue')
plt.show()
